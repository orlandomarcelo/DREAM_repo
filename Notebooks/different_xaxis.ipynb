# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib widget

import importlib
import os
import sys

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

import ExperimentClass

# %%
def clean_spaces(vector):
    clean_vector = []
    for k in vector:
        try:
            clean_vector.append(float(k.strip()))
        except ValueError:
            clean_vector.append(float('nan'))
    return clean_vector

# %%
importlib.reload(ExperimentClass)
sinus_JTS = ExperimentClass.Experiment("20230216_lum_sinus", "JTS", diff_xaxis = True)
fluo_data = ExperimentClass.Experiment("20221117_validation_cellule_unique","Fluo_Liquide_Data")

# %%
plt.figure()
time = []
for i, k in enumerate(sinus_JTS.clean_data):
    if i == 0:
        time.append(sinus_JTS.clean_times[i])
        plt.plot(time[i],k)
    else:
        time.append(sinus_JTS.clean_times[i]+time[i-1][-1])
        plt.plot(time[i],k)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
sinus_JTS.clean_times[i]+sinus_JTS.clean_times[i-1][-1]
# Out:
# array([30501.02, 31001.02, 31501.02, 32001.02, 32501.02, 33001.02,
#        33501.02, 34001.02, 34501.02, 35001.02, 35501.02, 36001.02,
#        36501.02, 37001.02, 37501.02, 38001.02, 38501.02, 39001.02,
#        39501.02, 40001.02, 40202.02, 40402.02, 40602.02, 40802.02,
#        41002.02, 41202.02, 41402.02, 41602.02, 41802.02, 42002.02,
#        42202.02, 42402.02, 42602.02, 42802.02, 43002.02, 43202.02,
#        43402.02, 43602.02, 43802.02, 44002.02, 44202.02, 44402.02,
#        44602.02, 44802.02, 45002.02, 45202.02, 45402.02, 45602.02,
#        45802.02, 46002.02, 46202.02, 46402.02, 46602.02, 46802.02,
#        47002.02, 47202.02, 47402.02, 47602.02, 47802.02, 48002.02,
#        48202.02, 48402.02, 48602.02, 48802.02, 49002.02, 49202.02,
#        49402.02, 49602.02, 49802.02, 50002.02, 50202.02, 50402.02,
#        50602.02, 50802.02, 51002.02, 51202.02, 51402.02, 51602.02,
#        51802.02, 52002.02, 52202.02, 52402.02, 52602.02, 52802.02,
#        53002.02, 53202.02, 53402.02, 53602.02, 53802.02, 54002.02,
#        54202.02, 54402.02, 54602.02, 54802.02, 55002.02, 55202.02,
#        55402.02, 55602.02, 55802.02, 56002.02, 56202.02, 56402.02,
#        56602.02, 56802.02, 57002.02, 57202.02, 57402.02, 57602.02,
#        57802.02, 58002.02, 58202.02, 58402.02, 58602.02, 58802.02,
#        59002.02, 59202.02, 59402.02, 59602.02, 59802.02, 60002.02,
#        60002.02])
