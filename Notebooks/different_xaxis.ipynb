# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib widget

import importlib
import os
import sys

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

import ExperimentClass

# %%
def clean_spaces(vector):
    clean_vector = []
    for k in vector:
        try:
            clean_vector.append(float(k.strip()))
        except ValueError:
            clean_vector.append(float('nan'))
    return clean_vector

# %%
importlib.reload(ExperimentClass)
sinus_JTS = ExperimentClass.Experiment("20230216_lum_sinus", "JTS", diff_xaxis = True)
fluo_data = ExperimentClass.Experiment("20221117_validation_cellule_unique","Fluo_Liquide_Data")

# %%
plt.figure()
time = []
for i, k in enumerate(sinus_JTS.clean_data):
    if i == 0:
        time.append(sinus_JTS.clean_times[i])
        plt.plot(time[i],k)
    else:
        time.append(sinus_JTS.clean_times[i]+time[i-1][-1])
        plt.plot(time[i],k)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure()
time = []
for i, k in enumerate(sinus_JTS.clean_data):
    plt.plot(sinus_JTS.clean_times[i],k)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
