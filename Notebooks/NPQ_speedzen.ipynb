# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib widget

import importlib
import os
import sys

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

import ExperimentClass
import tools
import math_functions as mf

# %%
manip = ExperimentClass.Experiment("20230807_NPQ_turbidostat", "SpeedZen")

# %%
normalising_vector = []
for col in manip.Data.columns:
    normalising_vector.append(manip.Data[col][4])
    manip.Data[col] = manip.Data[col]/manip.Data[col][4]

manip.annotations
# Out:
#     Record  Channel Souche
# 0       31        1   WT4A
# 1       32        2   WT4A
# 2       33        3   t222
# 3       34        4   t222
# 4       35        5  cc124
# 5       36        6  cc124
# 6       37        7  cc125
# 7       38        8  cc125
# 8       41        1   WT4A
# 9       42        2   WT4A
# 10      43        3   t222
# 11      44        4   t222
# 12      45        5  cc124
# 13      46        6  cc124
# 14      47        7  cc125
# 15      48        8  cc125

# %%
souches = ["WT4A", "t222", "cc124", "cc125"]

for i, k in enumerate(souches):
    records = list(manip.annotations[manip.annotations.Souche == souches[0]].Record)
    fig, ax = plt.subplots()
    fig.suptitle(f"{k}")
    for record in records:
        ax.plot(manip.Time, manip.Data[f"E{record}"], label = record)
        ax.legend()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
souches = ["WT4A", "t222", "cc124", "cc125"]
list(manip.annotations[manip.annotations.Souche == souches[0]].Record)
# Out:
# [31, 32, 41, 42]
