# %%
import pandas as pd
import numpy as np
import alienlab.utils
import matplotlib.pyplot as plt
from tkinter.filedialog import askopenfilename
import alienlab.plot
p = alienlab.plot.PlotFigure()

# %% [markdown]
# # Observation for 1 day at constant light and different light levels.

# %% [markdown]
# ### DO 1

# %%
path = askopenfilename()
# Blank file analysis
file = pd.read_csv(path, engine = 'python',
                         sep = ',', dtype = np.float64)
#bode_file = bode_file.dropna() #remove unnecessary rows
K = file.keys()
print(K)
file.plot(K[1], K[2], logx=False)

filtre_1_x = np.asarray(file[K[1]])
filtre_1_y = np.asarray(file[K[2]])
# Out:
# Index(['Unnamed: 0', 'Offset (V) intensity', 'Amplitude (V) intensity'], dtype='object')

# %% [markdown]
# # DO 3

# %%
path = askopenfilename()
# Blank file analysis
file = pd.read_csv(path, engine = 'python',
                         sep = ',', dtype = np.float64)
#bode_file = bode_file.dropna() #remove unnecessary rows
K = file.keys()
print(K)
file.plot(K[1], K[2], logx=False)
filtre_3_x = np.asarray(file[K[1]])
filtre_3_y = np.asarray(file[K[2]])
# Out:
# Index(['Unnamed: 0', 'Offset (V) intensity', 'Amplitude (V) intensity'], dtype='object')

# %% [markdown]
# # DO 2

# %%
path = askopenfilename()
# Blank file analysis
file = pd.read_csv(path, engine = 'python',
                         sep = ',', dtype = np.float64)
#bode_file = bode_file.dropna() #remove unnecessary rows
K = file.keys()
print(K)
file.plot(K[1], K[2], logx=False)
filtre_2_x = np.asarray(file[K[1]])
filtre_2_y = np.asarray(file[K[2]])
# Out:
# Index(['Unnamed: 0', 'Offset (V) intensity', 'Amplitude (V) intensity'], dtype='object')

# %%
plt.plot(filtre_1_x*100, filtre_1_y, label = '1')
plt.plot(filtre_2_x*10, filtre_2_y, label = '2')
plt.plot(filtre_3_x, filtre_3_y, label = '3')
plt.legend()

# %%
filtre_1_x
# Out:
# array([0.1       , 0.23448276, 0.36896552, 0.50344828, 0.63793103,
#        0.77241379, 0.90689655, 1.04137931, 1.17586207, 1.31034483,
#        1.44482759, 1.57931034, 1.7137931 , 1.84827586, 1.98275862,
#        2.11724138, 2.25172414, 2.3862069 , 2.52068966, 2.65517241,
#        2.78965517, 2.92413793, 3.05862069, 3.19310345, 3.32758621,
#        3.46206897, 3.59655172, 3.73103448, 3.86551724, 4.        ])
